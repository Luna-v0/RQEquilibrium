# %%
import pyspiel
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import sys, os
# Adjusting the location of the src folder
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))  
src_path     = os.path.join(project_root, "src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# %%
from RQE import RQE
from open_spiel_api import get_matrix

# %%
df = pd.read_csv('../data/open_spigel_games.csv')
df = df[df.type == 'one_shot']
df = df[df.min_n_players == 2]
df
# Out:
#     Unnamed: 0                    id                          name  \
# 7            7                blotto                        Blotto
# 55          55            matrix_bos            Bach or Stravinsky
# 56          56           matrix_brps  Biased Rock, Paper, Scissors
# 57          57             matrix_cd                  Chicken-Dare
# 58          58   matrix_coordination                  Coordination
# 59          59             matrix_mp              Matching Pennies
# 60          60             matrix_pd            Prisoner's Dilemma
# 61          61            matrix_rps         Rock, Paper, Scissors
# 62          62           matrix_rpsw  Rock, Paper, Scissors, Water
# 63          63             matrix_sh                     Stag Hunt
# 64          64  matrix_shapleys_game                Shapley's Game
# 73          73              nfg_game                      nfg_game
#
#     min_n_players  max_n_players      type  is_deterministic
# 7               2             10  one_shot              True
# 55              2              2  one_shot              True
# 56              2              2  one_shot              True
# 57              2              2  one_shot              True
# 58              2              2  one_shot              True
# 59              2              2  one_shot              True
# 60              2              2  one_shot              True
# 61              2              2  one_shot              True
# 62              2              2  one_shot              True
# 63              2              2  one_shot              True
# 64              2              2  one_shot              True
# 73              2            100  one_shot              True

# %%
# Out:
#     Unnamed: 0                    id                          name  \
# 7            7                blotto                        Blotto
# 55          55            matrix_bos            Bach or Stravinsky
# 56          56           matrix_brps  Biased Rock, Paper, Scissors
# 57          57             matrix_cd                  Chicken-Dare
# 58          58   matrix_coordination                  Coordination
# 59          59             matrix_mp              Matching Pennies
# 60          60             matrix_pd            Prisoner's Dilemma
# 61          61            matrix_rps         Rock, Paper, Scissors
# 62          62           matrix_rpsw  Rock, Paper, Scissors, Water
# 63          63             matrix_sh                     Stag Hunt
# 64          64  matrix_shapleys_game                Shapley's Game
# 73          73              nfg_game                      nfg_game
#
#     min_n_players  max_n_players      type  is_deterministic
# 7               2             10  one_shot              True
# 55              2              2  one_shot              True
# 56              2              2  one_shot              True
# 57              2              2  one_shot              True
# 58              2              2  one_shot              True
# 59              2              2  one_shot              True
# 60              2              2  one_shot              True
# 61              2              2  one_shot              True
# 62              2              2  one_shot              True
# 63              2              2  one_shot              True
# 64              2              2  one_shot              True
# 73              2            100  one_shot              True

# %%
param_grid = {
    "tau1": [0.001, 0.003, 0.06, 0.05, 0.1 ],
    "ep1": [110,130,170,190],
    "tau2": [0.001, 0.003, 0.06, 0.05, 0.1 ],
    "ep2": [110,130,170,190],
}

grid = list()

for game_name in df.id:
    game = pyspiel.load_matrix_game(game_name)
    for params in grid:
        rqe_solver = RQE(players=[
            Player(game_matrix=game.col_utilities(), tau=params["tau1"], epsilon=params["ep1"]),
            Player(game_matrix=game.row_utilities(), tau=params["tau2"], epsilon=params["ep2"])
        ])
        pi1, pi2 = rqe_solve.optimize()
        max_val_p1 = np.argmax(pi1)
        max_val_p2 = np.argmax(pi2)
# Out:
# 66
# 2
# 3
# 2
# 2
# 2
# 2
# 3
# 4
# 2
# 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 for game_name in df.id:
# ----> 2     game = pyspiel.load_matrix_game(game_name)
#       3     print(len(game.col_utilities()))
#
# IndexError: map::at
